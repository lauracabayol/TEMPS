# %%
import numpy as np
import pandas as pd
from astropy.io import fits
import os
from astropy.table import Table
from scipy.spatial import KDTree

import matplotlib.pyplot as plt

from IPython.display import Image
from IPython.core.display import HTML

# %%
import torch
from torch.utils.data import DataLoader, dataset, TensorDataset
from torch import nn, optim
from torch.optim import lr_scheduler

# %%
import sys
sys.path.append('../insight')
from archive import archive 
from insight_arch import Photoz_network
from insight import Insight_module
from utils import sigma68, nmad, plot_photoz_estimates
from scipy import stats

# %%
from matplotlib import rcParams
rcParams["mathtext.fontset"] = "stix"
rcParams["font.family"] = "STIXGeneral"
parent_dir = '/data/astro/scratch/lcabayol/Euclid/NNphotozs/Euclid_EXT_MER_PHZ_DC2_v1.5'

# %%
photoz_archive = archive(path = parent_dir, Qz_cut=1)
f, ferr, specz, specqz = photoz_archive.get_training_data()

# %%
nnz = Photoz_network(num_gauss=4)

# %%
insight = Insight_module(nnz)
insight.train(input_data=f, target_data=specz, nepochs=500, val_fraction=0.1, lr=1e-3)
# Out:
# training_loss:-0.31663596630096436 testing_loss:0.18577559292316437
# training_loss:-0.7506484985351562 testing_loss:-0.9807698130607605
# training_loss:-1.0342140197753906 testing_loss:-0.23623903095722198
# training_loss:0.078019879758358 testing_loss:-0.44159936904907227
# training_loss:-0.18709924817085266 testing_loss:-0.1983226090669632
# training_loss:-0.7703551650047302 testing_loss:-1.3030306100845337
# training_loss:-0.8252442479133606 testing_loss:-0.7545361518859863
# training_loss:-0.7536283731460571 testing_loss:-1.1309820413589478
# training_loss:-0.8647240996360779 testing_loss:-0.8650542497634888
# training_loss:-0.7159114480018616 testing_loss:-0.5620269775390625
# training_loss:-0.6110644936561584 testing_loss:-0.4890943169593811
# training_loss:-1.1393110752105713 testing_loss:0.03125639632344246
# training_loss:-0.3480193316936493 testing_loss:-1.4824607372283936
# training_loss:-1.0076358318328857 testing_loss:-0.7955071330070496
# training_loss:-0.5860822200775146 testing_loss:-0.2660488486289978
# training_loss:-1.4954043626785278 testing_loss:-1.2902734279632568
# training_loss:-1.0125110149383545 testing_loss:-1.534846305847168
# training_loss:-1.2943527698516846 testing_loss:-0.6718124747276306
# training_loss:-1.4350335597991943 testing_loss:0.025091171264648438
# training_loss:-0.17392432689666748 testing_loss:-0.7784516215324402
# training_loss:-0.9933975338935852 testing_loss:-1.27727472782135
# training_loss:-1.1509991884231567 testing_loss:-0.691932737827301
# training_loss:-0.4008868336677551 testing_loss:-0.6085060238838196
# training_loss:-0.6664854288101196 testing_loss:-1.5206218957901
# training_loss:-1.1121652126312256 testing_loss:-0.9302613139152527
# training_loss:-0.8780136704444885 testing_loss:-0.5545962452888489
# training_loss:-0.598385751247406 testing_loss:-1.2749828100204468
# training_loss:-0.5608516335487366 testing_loss:-1.253127098083496
# training_loss:-0.7307500243186951 testing_loss:-1.3599956035614014
# training_loss:-1.357422113418579 testing_loss:-1.1718207597732544
# training_loss:-1.0532201528549194 testing_loss:-1.1279398202896118
# training_loss:-0.7720513343811035 testing_loss:-0.5878702998161316
# training_loss:-1.0432748794555664 testing_loss:-0.9494971632957458
# training_loss:-0.07673917710781097 testing_loss:-0.5286681056022644
# training_loss:-1.3553615808486938 testing_loss:-1.7273977994918823
# training_loss:-0.6780700087547302 testing_loss:-1.282497763633728
# training_loss:-1.3378267288208008 testing_loss:-0.1444624662399292
# training_loss:-1.2823110818862915 testing_loss:-1.1826690435409546
# training_loss:-0.47460535168647766 testing_loss:-1.5380126237869263
# training_loss:-0.963798999786377 testing_loss:-1.5168272256851196
# training_loss:-0.656769871711731 testing_loss:0.9805960655212402
# training_loss:-0.4991021752357483 testing_loss:-1.3514384031295776
# training_loss:-1.201236367225647 testing_loss:-1.709517240524292
# training_loss:-0.6821452975273132 testing_loss:-0.6305388808250427
# training_loss:-1.1317800283432007 testing_loss:-0.8971928954124451
# training_loss:-1.0090250968933105 testing_loss:-1.3592705726623535
# training_loss:-1.005216121673584 testing_loss:-1.8519328832626343
# training_loss:-1.1865341663360596 testing_loss:-1.0523998737335205
# training_loss:-0.7459039092063904 testing_loss:-0.4674842655658722
# training_loss:-0.18076440691947937 testing_loss:-0.2765936255455017
# training_loss:-0.9198161363601685 testing_loss:-0.22741635143756866
# training_loss:-1.0070641040802002 testing_loss:-0.8812887072563171
# training_loss:-1.1218616962432861 testing_loss:-1.061684250831604
# training_loss:0.019347235560417175 testing_loss:-0.8256726861000061
# training_loss:-0.5519084334373474 testing_loss:-0.747234046459198
# training_loss:-1.0881483554840088 testing_loss:-1.2520222663879395
# training_loss:-1.2171541452407837 testing_loss:-1.1971216201782227
# training_loss:-1.0496788024902344 testing_loss:-0.6852992177009583
# training_loss:-1.3844670057296753 testing_loss:-0.7627688646316528
# training_loss:-1.3956634998321533 testing_loss:-1.416364312171936
# training_loss:-1.5333356857299805 testing_loss:-1.2485657930374146
# training_loss:-0.6844561696052551 testing_loss:-1.034386157989502
# training_loss:-1.0159672498703003 testing_loss:-1.8104246854782104
# training_loss:-1.309048056602478 testing_loss:-0.7413343191146851
# training_loss:-0.9788079261779785 testing_loss:-0.6098204851150513
# training_loss:-0.9148761034011841 testing_loss:-0.7306521534919739
# training_loss:-0.837659478187561 testing_loss:-1.1381113529205322
# training_loss:-0.4059925675392151 testing_loss:-0.573918879032135
# training_loss:-1.1457726955413818 testing_loss:-1.7619779109954834
# training_loss:-1.273679256439209 testing_loss:-1.9733504056930542
# training_loss:-0.5658974051475525 testing_loss:-0.9485756754875183
# training_loss:-1.2524518966674805 testing_loss:-1.0308411121368408
# training_loss:-1.1596665382385254 testing_loss:-1.5089468955993652
# training_loss:-0.9021334648132324 testing_loss:-1.2770869731903076
# training_loss:-1.0804001092910767 testing_loss:-1.0405189990997314
# training_loss:-0.8987933397293091 testing_loss:0.3953123092651367
# training_loss:-1.1747384071350098 testing_loss:-0.5258921980857849
# training_loss:-0.9975948333740234 testing_loss:-1.6258307695388794
# training_loss:-0.743851900100708 testing_loss:-0.8711583018302917
# training_loss:-1.2314213514328003 testing_loss:-1.2120096683502197
# training_loss:-0.22374646365642548 testing_loss:-0.8280205726623535
# training_loss:-0.7311931252479553 testing_loss:-1.3487093448638916
# training_loss:-1.084967851638794 testing_loss:-1.3520269393920898
# training_loss:-1.4831573963165283 testing_loss:-0.9708278179168701
# training_loss:-1.1614561080932617 testing_loss:-0.7701470851898193
# training_loss:-1.1026736497879028 testing_loss:-1.095813274383545
# training_loss:-1.0473347902297974 testing_loss:0.06479883193969727
# training_loss:-1.2177990674972534 testing_loss:-1.340427041053772
# training_loss:-0.9763546586036682 testing_loss:-1.063799262046814
# training_loss:-1.4529776573181152 testing_loss:-1.2076951265335083
# training_loss:-0.4972916543483734 testing_loss:-1.2684571743011475
# training_loss:-1.232815146446228 testing_loss:-1.0557998418807983
# training_loss:-1.2098318338394165 testing_loss:-0.6236100196838379
# training_loss:-1.4339654445648193 testing_loss:-0.3129662573337555
# training_loss:-1.0413076877593994 testing_loss:-0.9415382146835327
# training_loss:-0.49956265091896057 testing_loss:-0.5933409929275513
# training_loss:-0.8159158825874329 testing_loss:-1.3414109945297241
# training_loss:-1.2535886764526367 testing_loss:-1.1691795587539673
# training_loss:-1.0433859825134277 testing_loss:-0.9687842130661011
# training_loss:-0.9701303839683533 testing_loss:-0.5916429758071899
# training_loss:-1.0350509881973267 testing_loss:-0.6143068075180054
# training_loss:-1.5352734327316284 testing_loss:-1.4308820962905884
# training_loss:-0.9179251790046692 testing_loss:-1.2772397994995117
# training_loss:-0.9458326101303101 testing_loss:-1.310457468032837
# training_loss:-0.8284637331962585 testing_loss:-1.0811713933944702
# training_loss:-1.4760862588882446 testing_loss:-1.1042672395706177
# training_loss:-1.370448112487793 testing_loss:-1.0925356149673462
# training_loss:-0.9433906078338623 testing_loss:-1.2398128509521484
# training_loss:-1.1315757036209106 testing_loss:-1.4656084775924683
# training_loss:-0.8333658576011658 testing_loss:-1.2641714811325073
# training_loss:-1.1612037420272827 testing_loss:-0.5846045613288879
# training_loss:-0.5686818957328796 testing_loss:-0.9818854331970215
# training_loss:-0.8073000311851501 testing_loss:-1.047784686088562
# training_loss:-0.6368224620819092 testing_loss:-0.9926685094833374
# training_loss:-1.1380484104156494 testing_loss:-1.6154063940048218
# training_loss:-1.2792476415634155 testing_loss:-1.379647135734558
# training_loss:-1.376906156539917 testing_loss:-0.8935562968254089
# training_loss:-0.7181461453437805 testing_loss:-1.0520678758621216
# training_loss:-1.343970775604248 testing_loss:-1.1044718027114868
# training_loss:-1.0835894346237183 testing_loss:-1.9297422170639038
# training_loss:-0.8854701519012451 testing_loss:-1.3966150283813477
# training_loss:-0.8191279768943787 testing_loss:-0.8644329905509949
# training_loss:-1.5420153141021729 testing_loss:-0.8821649551391602
# training_loss:-1.343662142753601 testing_loss:-1.5057002305984497
# training_loss:-0.35109052062034607 testing_loss:-0.4661344289779663
# training_loss:-1.2383953332901 testing_loss:-1.0535613298416138
# training_loss:-1.4341802597045898 testing_loss:-0.5972636342048645
# training_loss:-0.009474623017013073 testing_loss:-0.36064594984054565
# training_loss:-0.47807759046554565 testing_loss:-1.0463218688964844
# training_loss:-1.2709996700286865 testing_loss:-0.7824171185493469
# training_loss:-0.7836264371871948 testing_loss:-0.4295158386230469
# training_loss:-1.1002793312072754 testing_loss:-0.7410542964935303
# training_loss:-1.5248701572418213 testing_loss:-0.986728847026825
# training_loss:-1.0697065591812134 testing_loss:-1.4820451736450195
# training_loss:-0.8444833159446716 testing_loss:-1.0017576217651367
# training_loss:-0.7867075204849243 testing_loss:-1.324030876159668
# training_loss:-0.8214920163154602 testing_loss:-1.2126867771148682
# training_loss:-0.7990449070930481 testing_loss:-1.2082773447036743
# training_loss:-1.1946407556533813 testing_loss:-0.7550921440124512
# training_loss:-1.4344650506973267 testing_loss:-1.5821425914764404
# training_loss:-1.098026990890503 testing_loss:-1.2258249521255493
# training_loss:-1.599576711654663 testing_loss:-1.1537058353424072
# training_loss:-1.1203254461288452 testing_loss:-1.6262987852096558
# training_loss:-0.21143442392349243 testing_loss:-1.20799720287323
# training_loss:-1.2106610536575317 testing_loss:-0.8789585828781128
# training_loss:-0.8474045991897583 testing_loss:-1.5317915678024292
# training_loss:-0.7960692048072815 testing_loss:-0.6443920135498047
# training_loss:-1.1560941934585571 testing_loss:-1.4505306482315063
# training_loss:-1.2003545761108398 testing_loss:-1.1779886484146118
# training_loss:-1.4474692344665527 testing_loss:-1.5297441482543945
# training_loss:-0.5969364047050476 testing_loss:-1.4086493253707886
# training_loss:-1.38947331905365 testing_loss:-1.088106632232666
# training_loss:-1.666460394859314 testing_loss:-1.8990129232406616
# training_loss:-0.6371588706970215 testing_loss:-0.6267538070678711
# training_loss:-1.0930770635604858 testing_loss:-1.2481151819229126
# training_loss:-0.7180777192115784 testing_loss:-1.3378866910934448
# training_loss:-1.05417001247406 testing_loss:-0.7519786953926086
# training_loss:-1.4177730083465576 testing_loss:-0.9336007237434387
# training_loss:-1.0639010667800903 testing_loss:-0.41415834426879883
# training_loss:-1.2951170206069946 testing_loss:-1.9297205209732056
# training_loss:-1.0876574516296387 testing_loss:-0.9609362483024597
# training_loss:-1.1352084875106812 testing_loss:-1.3923251628875732
# training_loss:-0.9769161343574524 testing_loss:1.2264307737350464
# training_loss:-1.2925611734390259 testing_loss:-0.9151756167411804
# training_loss:-1.2709996700286865 testing_loss:-1.6020416021347046
# training_loss:-1.4896950721740723 testing_loss:-0.3902150094509125
# training_loss:-0.848455548286438 testing_loss:-1.587514042854309
# training_loss:-0.9805473685264587 testing_loss:-1.6960971355438232
# training_loss:-1.283568263053894 testing_loss:-0.8257694244384766
# training_loss:-1.3345463275909424 testing_loss:-1.198311448097229
# training_loss:-1.2508935928344727 testing_loss:-0.3165137469768524
# training_loss:-1.4397858381271362 testing_loss:-1.8370046615600586
# training_loss:-0.7852041125297546 testing_loss:-1.5533487796783447
# training_loss:-1.4994001388549805 testing_loss:-0.1769072264432907
# training_loss:-1.1655707359313965 testing_loss:-1.2230885028839111
# training_loss:-1.1136568784713745 testing_loss:-1.3677864074707031
# training_loss:-1.3441988229751587 testing_loss:-0.7588308453559875
# training_loss:-1.514310359954834 testing_loss:-1.5439294576644897
# training_loss:-1.3713873624801636 testing_loss:-0.9705389738082886
# training_loss:-1.195888638496399 testing_loss:-1.0508099794387817
# training_loss:-1.2842518091201782 testing_loss:-1.0602080821990967
# training_loss:-1.4499485492706299 testing_loss:-1.3555712699890137
# training_loss:-1.6975210905075073 testing_loss:-1.167443037033081
# training_loss:-1.1090455055236816 testing_loss:-1.1247713565826416
# training_loss:-1.493228793144226 testing_loss:-1.7782726287841797
# training_loss:-0.6280897855758667 testing_loss:-1.7031184434890747
# training_loss:-0.9562180638313293 testing_loss:-2.2130868434906006
# training_loss:-1.1467567682266235 testing_loss:-1.7991842031478882
# training_loss:-1.5655217170715332 testing_loss:-1.3009144067764282
# training_loss:-0.7571691274642944 testing_loss:-1.0256706476211548
# training_loss:-1.5629032850265503 testing_loss:-1.4266477823257446
# training_loss:-1.5915015935897827 testing_loss:-1.5560942888259888
# training_loss:-1.156670093536377 testing_loss:-1.0196551084518433
# training_loss:-1.0855575799942017 testing_loss:-0.4659513235092163
# training_loss:-0.9985039234161377 testing_loss:-1.005774974822998
# training_loss:-1.3589650392532349 testing_loss:-1.0209264755249023
# training_loss:-1.404725193977356 testing_loss:-1.1112922430038452
# training_loss:-1.2856825590133667 testing_loss:-1.2284510135650635
# training_loss:-0.9969373345375061 testing_loss:-0.8779969811439514
# training_loss:-0.923977792263031 testing_loss:-1.4006181955337524
# training_loss:-0.9139819145202637 testing_loss:-1.6855247020721436
# training_loss:-1.1823748350143433 testing_loss:-0.8146784901618958
# training_loss:-0.9188883304595947 testing_loss:-1.8008853197097778
# training_loss:-1.5587975978851318 testing_loss:-0.9678481817245483
# training_loss:-1.2660753726959229 testing_loss:-0.8022269606590271
# training_loss:-1.2516705989837646 testing_loss:-1.1226191520690918
# training_loss:-0.9580478072166443 testing_loss:5.889923095703125
# training_loss:-0.40579405426979065 testing_loss:-0.1817208081483841
# training_loss:-1.5668646097183228 testing_loss:-1.0633209943771362
# training_loss:-1.0111260414123535 testing_loss:-0.7934398055076599
# training_loss:-1.176985740661621 testing_loss:-0.5787568688392639
# training_loss:-0.9078634977340698 testing_loss:-1.5201441049575806
# training_loss:-1.3603061437606812 testing_loss:-1.4966857433319092
# training_loss:-1.1773500442504883 testing_loss:-0.69846510887146
# training_loss:-1.666892170906067 testing_loss:-1.3959038257598877
# training_loss:-1.2691986560821533 testing_loss:-1.3556427955627441
# training_loss:-1.4327689409255981 testing_loss:-1.41000497341156
# training_loss:-1.4469480514526367 testing_loss:-1.045111894607544
# training_loss:-1.2442795038223267 testing_loss:-1.22956383228302
# training_loss:-1.4557733535766602 testing_loss:-1.540167212486267
# training_loss:-1.3743761777877808 testing_loss:-1.395784616470337
# training_loss:-1.6901047229766846 testing_loss:0.473287433385849
# training_loss:-1.105675220489502 testing_loss:-1.2363554239273071
# training_loss:-0.5455407500267029 testing_loss:-1.4646822214126587
# training_loss:-1.269223928451538 testing_loss:-1.0813425779342651
# training_loss:-0.7282266020774841 testing_loss:-1.4365062713623047
# training_loss:-0.8990478515625 testing_loss:-1.2571173906326294
# training_loss:-1.1976025104522705 testing_loss:-0.8356563448905945
# training_loss:-1.3976926803588867 testing_loss:-1.1596767902374268
# training_loss:-0.8223131895065308 testing_loss:-1.3292914628982544
# training_loss:-1.0474470853805542 testing_loss:-0.16693632304668427
# training_loss:-1.3900783061981201 testing_loss:-0.32508906722068787
# training_loss:-1.1956815719604492 testing_loss:-1.487714409828186
# training_loss:-0.6093094944953918 testing_loss:-0.8580958843231201
# training_loss:-1.5775314569473267 testing_loss:-0.8934945464134216
# training_loss:-1.082561731338501 testing_loss:-1.2011432647705078
# training_loss:-0.8253197073936462 testing_loss:-0.5954218506813049
# training_loss:-1.2187551259994507 testing_loss:-0.6871485114097595
# training_loss:-1.3098106384277344 testing_loss:-1.43653404712677
# training_loss:-1.2490828037261963 testing_loss:-0.7824040651321411
# training_loss:-1.0498512983322144 testing_loss:-0.9188193678855896
# training_loss:-1.2731956243515015 testing_loss:-0.6110891699790955
# training_loss:-1.6009602546691895 testing_loss:-0.9612151980400085
# training_loss:-1.8835387229919434 testing_loss:-1.7571463584899902
# training_loss:-1.380652666091919 testing_loss:-0.1664152890443802
# training_loss:-1.5202772617340088 testing_loss:-1.4922083616256714
# training_loss:-0.9181127548217773 testing_loss:-2.0337557792663574
# training_loss:-1.0301127433776855 testing_loss:-0.7326280474662781
# training_loss:-1.0139551162719727 testing_loss:-1.7049471139907837
# training_loss:-1.116806983947754 testing_loss:-1.8285304307937622
# training_loss:-1.6582260131835938 testing_loss:-1.3040961027145386
# training_loss:-1.3108623027801514 testing_loss:1.4443141222000122
# training_loss:-1.5295946598052979 testing_loss:-0.7490592002868652
# training_loss:-1.6537611484527588 testing_loss:-1.5789819955825806
# training_loss:-1.330317497253418 testing_loss:-1.2213797569274902
# training_loss:-1.4656285047531128 testing_loss:-1.21807062625885
# training_loss:-1.3059983253479004 testing_loss:-1.2957422733306885
# training_loss:-1.406136393547058 testing_loss:-0.6397973895072937
# training_loss:-1.3745980262756348 testing_loss:-1.8028799295425415
# training_loss:-0.9357537627220154 testing_loss:-0.7280221581459045
# training_loss:-0.8899737596511841 testing_loss:-0.905056357383728
# training_loss:-1.17713463306427 testing_loss:-0.8464610576629639
# training_loss:-1.5099589824676514 testing_loss:-0.9709958434104919
# training_loss:-1.2024129629135132 testing_loss:-1.1477651596069336
# training_loss:-1.4740791320800781 testing_loss:-0.1577340066432953
# training_loss:-1.7473636865615845 testing_loss:-1.6849920749664307
# training_loss:-1.243930459022522 testing_loss:-0.9931924343109131
# training_loss:-1.5045197010040283 testing_loss:-1.6357702016830444
# training_loss:-1.5481678247451782 testing_loss:-0.4513358771800995
# training_loss:-1.5326220989227295 testing_loss:-0.9909722208976746
# training_loss:-1.7418068647384644 testing_loss:-1.003135085105896
# training_loss:-0.985914409160614 testing_loss:-0.4563041627407074
# training_loss:-1.8560895919799805 testing_loss:-1.297991394996643
# training_loss:-1.4081131219863892 testing_loss:-1.0402076244354248
# training_loss:-1.4614609479904175 testing_loss:-0.41408777236938477
# training_loss:-1.3668770790100098 testing_loss:-1.1625880002975464
# training_loss:-1.6846039295196533 testing_loss:-1.8057008981704712
# training_loss:-1.2046364545822144 testing_loss:-1.6054580211639404
# training_loss:-1.3671247959136963 testing_loss:-1.2291481494903564
# training_loss:-1.5193692445755005 testing_loss:-1.286891222000122
# training_loss:-1.511146903038025 testing_loss:-0.4732470214366913
# training_loss:-1.0230361223220825 testing_loss:-0.9720691442489624
# training_loss:-1.676430106163025 testing_loss:-0.9995797872543335
# training_loss:-0.722807765007019 testing_loss:8.604046821594238
# training_loss:-1.3244929313659668 testing_loss:-1.119666337966919
# training_loss:-1.646761178970337 testing_loss:-2.052985906600952
# training_loss:-1.2254180908203125 testing_loss:-0.6264074444770813
# training_loss:-1.1913328170776367 testing_loss:-1.2809981107711792
# training_loss:-0.6108806133270264 testing_loss:-1.2467896938323975
# training_loss:-0.7445117235183716 testing_loss:-0.6904229521751404
# training_loss:-1.0841143131256104 testing_loss:-1.1977959871292114
# training_loss:-1.3461724519729614 testing_loss:-0.3981589376926422
# training_loss:-1.0043753385543823 testing_loss:-1.7354838848114014
# training_loss:-1.6568701267242432 testing_loss:-1.219857096672058
# training_loss:-0.24954475462436676 testing_loss:-1.1830178499221802
# training_loss:-1.1321475505828857 testing_loss:-0.9736999273300171
# training_loss:-1.2771389484405518 testing_loss:-1.0872862339019775
# training_loss:-1.6208115816116333 testing_loss:-1.2472198009490967
# training_loss:-0.7312105894088745 testing_loss:-0.6753965616226196
# training_loss:-1.4251947402954102 testing_loss:-0.8958294987678528

# %%
f_test, ferr_test, specz_test = photoz_archive.get_testing_data()

# %%
z,zerr = insight.get_photoz(input_data=torch.Tensor(f_test), target_data=torch.Tensor(specz_test))

# %%
from scipy.stats import gaussian_kde

# Calculate the point density
xy = np.vstack([specz_test,z])
zd = gaussian_kde(xy)(xy)

fig, ax = plt.subplots()
plt.scatter(specz_test, z,c=zd, s=1)
plt.xlim(0,5)
plt.ylim(0,5)

plt.xlabel(r'$z_{\rm s}$', fontsize = 14)
plt.ylabel('$z$', fontsize = 14)
# Out:
# Text(0, 0.5, '$z$')

# %%
from scipy.stats import gaussian_kde

# Calculate the point density
xy = np.vstack([specz_test,z])
#zd = gaussian_kde(xy)(xy)

fig, ax = plt.subplots()
plt.scatter(specz_test, z,c=zd, s=1)
plt.xlim(0,2)
plt.ylim(0,2)

plt.xlabel(r'$z_{\rm s}$', fontsize = 14)
plt.ylabel('$z$', fontsize = 14)
# Out:
# Text(0, 0.5, '$z$')

# %%
VISmag = photoz_archive.get_VIS_mag(photoz_archive.cat_test)

# %%
df_test = pd.DataFrame(np.c_[VISmag, specz_test,z,zerr], columns = ['VISmag','zs','z','zuncert'])
df_test['zwerr'] = (df_test.z -df_test.zs) / (1+df_test.zs)

# %%
def plot_photoz(df, nbins,xvariable,metric, type_bin='bin'):
    bin_edges = stats.mstats.mquantiles(df[xvariable].values, np.linspace(0.1,1,nbins))
    ydata,xdata = [],[]
    
    
    for k in range(len(bin_edges)-1):
        edge_min = bin_edges[k]
        edge_max = bin_edges[k+1]

        mean_mag =  (edge_max + edge_min) / 2
        
        if type_bin=='bin':
            df_plot = df_test[(df_test[xvariable] > edge_min) & (df_test[xvariable] < edge_max)]
        elif type_bin=='cum':
            df_plot = df_test[(df_test[xvariable] < edge_max)]
        else:
            raise ValueError("Only type_bin=='bin' for binned and 'cum' for cumulative are supported")


        xdata.append(mean_mag)
        if metric=='sig68':
            ydata.append(sigma68(df_plot.zwerr))
            ylab=r'$\sigma_{\rm NMAD} [\Delta z]$'
        elif metric=='bias':
            ydata.append(np.median(df_plot.zwerr))
            ylab=r'Median $[\Delta z]$'
        elif metric=='nmad':
            ydata.append(nmad(df_plot.zwerr))
            ylab=r'$\sigma_{\rm NMAD} [\Delta z]$'
        elif metric=='outliers':
            ydata.append(len(df_plot[np.abs(df_plot.zwerr)>0.15])/len(df_plot) *100)
            ylab=r'$\eta$ [%]'
            
    if xvariable=='VISmag':
        xlab='VIS'
    elif xvariable=='zs':
        xlab=r'$z_{\rm spec}$'
    elif xvariable=='z':
        xlab=r'$z$'

    plt.plot(xdata,ydata, ls = '-', marker = '.', color = 'navy',lw = 1, label = '')
    plt.ylabel(f'{ylab}', fontsize = 18)
    plt.xlabel(f'{xlab}', fontsize = 16)

    plt.xticks(fontsize = 14)
    plt.yticks(fontsize = 14)

    plt.grid(False)
    
    plt.show()

# %%
plot_photoz(df_test, 8,'z','bias', type_bin='bin')

# %%
nmad(df_test[df_test.VISmag<25].zwerr)
# Out:
# 0.05283824461551243

# %%
df_test = df_test[df_test.VISmag<25]

# %%
len(df_test[np.abs(df_test.zwerr)>0.15])/len(df_test)
# Out:
# 0.14763480282571761

# %%
torch.save(insight.model.state_dict(),'/data/astro/scratch/lcabayol/Euclid/NNphotozs/models/insight_v1.pt')

# %%
df_test.to_csv('/data/astro/scratch/lcabayol/Euclid/NNphotozs/results/df1.csv', sep=',')

# %%
# Create a list of additional header lines
header_lines = [
    "# Training spect-zs with a strict quality cut",
    "#10 MDN components",
    "# For 300 epochs with lr0=1e-3 + 100 epochs with lr=1e-4",
    "# Date: 2023-07-26",
]

# Write DataFrame to a CSV file with custom header lines
with open('/data/astro/scratch/lcabayol/Euclid/NNphotozs/results/df1.csv', 'w') as f:
    for line in header_lines:
        f.write(line + '\n')
    df_test.to_csv(f, header=True, index=False, line_terminator='\n')
# Out:
# /tmp/ipykernel_1010/2591005548.py:13: FutureWarning: the 'line_terminator'' keyword is deprecated, use 'lineterminator' instead.
#   df_test.to_csv(f, header=True, index=False, line_terminator='\n')
